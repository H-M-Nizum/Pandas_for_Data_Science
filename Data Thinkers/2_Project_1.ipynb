# %% [markdown]
# # DataSet : https://www.kaggle.com/datasets/utkarsharya/ecommerce-purchases

# %%
import pandas as pd
df = pd.read_csv("E:\Github Advance Python\Pandas_for_Data_Science\DS\Ecommerce Purchases")
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# # 1. Display Top 10 AND Last 3 Row Of The Dataset

# %%
df.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
df.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %% [markdown]
# ## 2. Check Datatype of Each Column and Number of Row-Column

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
print(df.shape)
print(f"Number of Row : {df.shape[0]}")
print(f"Number of Column : {df.shape[1]}")
# Out:
# (10000, 14)
# Number of Row : 10000
# Number of Column : 14

# %%
df.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %% [markdown]
# ## 3. Check Null Values in the Dataset

# %%
df.isnull()
# Out:
#       Address    Lot  AM or PM  Browser Info  Company  Credit Card  \
# 0       False  False     False         False    False        False
# 1       False  False     False         False    False        False
# 2       False  False     False         False    False        False
# 3       False  False     False         False    False        False
# 4       False  False     False         False    False        False
# ...       ...    ...       ...           ...      ...          ...
# 9995    False  False     False         False    False        False
# 9996    False  False     False         False    False        False
# 9997    False  False     False         False    False        False
# 9998    False  False     False         False    False        False
# 9999    False  False     False         False    False        False
#
#       CC Exp Date  CC Security Code  CC Provider  Email    Job  IP Address  \
# 0           False             False        False  False  False       False
# ...

# %%
df.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# ## 4. Highest, Lowest And Average purchase prices

# %%
df['Purchase Price'].max()
# Out:
# 99.99

# %%
df['Purchase Price'].min()
# Out:
# 0.0

# %%
df['Purchase Price'].mean()
# Out:
# 50.347302

# %% [markdown]
# ## 5. How Many people have French 'fr'AS their language

# %%
len(df[df['Language'] == 'fr'])
# Out:
# 1097

# %%
df[df['Language'] == 'fr'].count()
# Out:
# Address             1097
# Lot                 1097
# AM or PM            1097
# Browser Info        1097
# Company             1097
# Credit Card         1097
# CC Exp Date         1097
# CC Security Code    1097
# CC Provider         1097
# Email               1097
# Job                 1097
# IP Address          1097
# Language            1097
# Purchase Price      1097
# dtype: int64

# %% [markdown]
# ## 6. Job Title contains Engineer

# %%
df['Job'].str.contains('engineer')
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: Job, Length: 10000, dtype: bool

# %%
df['Job'].str.contains('engineer', 	case=True).sum()
# Out:
# 531

# %%
df['Job'].str.contains('engineer', 	case=False).sum()
# Out:
# 984

# %% [markdown]
# ## 7. Find Email of the person with the following IP address : 132.207.160.22

# %%
df[df['IP Address'] == '132.207.160.22']
# Out:
#                             Address    Lot AM or PM  \
# 2  Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
#
#                                         Browser Info  \
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
#
#                       Company   Credit Card CC Exp Date  CC Security Code  \
# 2  Simpson, Williams and Pham  675957666125       08/19               699
#
#     CC Provider                           Email                       Job  \
# 2  JCB 16 digit  amymiller@morales-harrison.com  Customer service manager
#
#        IP Address Language  Purchase Price
# 2  132.207.160.22       de            0.95

# %%
df[df['IP Address'] == '132.207.160.22']['Email']
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %% [markdown]
# ## 8. How many people have MasterCard AS their Credit Card provider and made a purchase above 50?

# %%
df[(df['CC Provider'] == 'Mastercard') & (df['Purchase Price'] > 50)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
len(df[(df['CC Provider'] == 'Mastercard') & (df['Purchase Price'] > 50)])
# Out:
# 405

# %% [markdown]
# ## 9. How many people purchase During the AM and How many people purchase During PM

# %%
df['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %%
# Purchase During the AM
len(df[df['AM or PM']== 'AM'])
# Out:
# 4932

# %%
# Purchase During the PM
len(df[df['AM or PM']== 'PM'])
# Out:
# 5068

# %% [markdown]
# ## 10. How Many people have A Credit Card that expires in 2020?

# %%
count = 0
for i in df['CC Exp Date']:
    if i[3:] == '20':
        count += 1
print(count)
# Out:
# 988

# %%
len(df[df['CC Exp Date'].apply(lambda x:x[3:] == '20')])
# Out:
# 988

# %% [markdown]
# ## 11. Top 5 most popular Email providers(e.g. gmail.com, yahoo.com, etc...)

# %%
list = []
for i in df['Email']:
    list.append(i.split('@')[1])
df['tem'] = list

# %%
df['tem'].value_counts().head()
# Out:
# tem
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %%
df.drop('tem', axis=1, inplace=True)

# %%
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
df['Email'].apply(lambda x:x.split('@')[1]).value_counts().head(6)
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# brown.com         29
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# # New Salary DataSet : https://www.kaggle.com/datasets/kaggle/sf-salaries

# %% [markdown]
# ## 1. Create DataFrame

# %%
new_df = pd.read_csv("E:\Github Advance Python\Pandas_for_Data_Science\DS\Salaries.csv")
new_df
# Out:
# C:\Users\ACT\AppData\Local\Temp\ipykernel_8968\2122199396.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   new_df = pd.read_csv("E:\Github Advance Python\Pandas_for_Data_Science\DS\Salaries.csv")
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %% [markdown]
# ## 2. Replace 'Not Provided' in EmployeeName column to NaN

# %%
import numpy as np
new_df['EmployeeName'] = new_df['EmployeeName'].replace('Not provided', np.nan)

# %%
new_df['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %% [markdown]
# ## 3. Drop the Rows having 3 missing values

# %%
new_df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             4
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
new_df.drop(new_df[new_df.isnull().sum(axis=1) == 3].index, axis=0)
# Out:
#             Id        EmployeeName                      JobTitle    BasePay  \
# 36159    36160      Gary Altenberg  Lieutenant, Fire Suppression  128808.87
# 36160    36161        Gregory Suhr               Chief of Police   302578.0
# 36161    36162          Khoa Trinh   Electronic Maintenance Tech   111921.0
# 36162    36163  Joanne Hayes-White        Chief, Fire Department  296943.01
# 36163    36164   Frederick Binkley     EMT/Paramedic/Firefighter  126863.19
# ...        ...                 ...                           ...        ...
# 148645  148646    Carolyn A Wilson     Human Services Technician       0.00
# 148647  148648      Joann Anderson   Communications Dispatcher 2       0.00
# 148648  148649         Leon Walker                     Custodian       0.00
# 148649  148650       Roy I Tillery                     Custodian       0.00
# 148653  148654           Joe Lopez    Counselor, Log Cabin Ranch       0.00
#
# ...

# %% [markdown]
# ## 4. Display Name of the perso Having the highest TotalPay.

# %%
new_df['TotalPay']
# Out:
# 0         567595.43
# 1         538909.28
# 2         335279.91
# 3         332343.61
# 4         326373.19
#             ...
# 148649         0.00
# 148650         0.00
# 148651         0.00
# 148652         0.00
# 148653      -618.13
# Name: TotalPay, Length: 148654, dtype: float64

# %%
new_df.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay              object
# OvertimePay          object
# OtherPay             object
# Benefits             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status               object
# dtype: object

# %%
new_df['TotalPay'].max()
# Out:
# 567595.43

# %%
new_df[new_df['TotalPay'] == new_df['TotalPay'].max()]['EmployeeName']
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %% [markdown]
# ## 5. Find Average TotalPay of All Employee per year

# %%
# Group by 'Year' and calculate the mean of 'TotalPay'
average_total_pay_per_year = new_df.groupby('Year')['TotalPay'].mean()

# Display the result
print(average_total_pay_per_year)
# Out:
# Year
# 2011    71744.103871
# 2012    74113.262265
# 2013    77611.443142
# 2014    75463.918140
# Name: TotalPay, dtype: float64
